# %% [markdown]
# # Acquire and Summarize:
# ### 1. Acquire data from the cloud database.
#
# You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
# Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid. - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.

# %%
#imports:
import pandas as pd
import numpy as np
import os
import env

# %%
# get connection url:
def get_db_url(db, user= env.user, host=env.host, password=env.password):
    """
    This function will:
    - take credentials from env.py file
    - make a connection to the SQL database with given credentials
    - return url connection
    """
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
# need a table that specifically: max logerror and max transactiondate

# %%
# sql query: 
sql_query_2 = '''
Select *
FROM properties_2017 as pr
	JOIN (Select 
	parcelid,
    max(logerror) as logerrorr, 
    max(transactiondate) as transactiondate
From
	predictions_2017
Group by parcelid) as predictions_2017 
	on predictions_2017.parcelid = pr.parcelid
	Left JOIN airconditioningtype as air 
		on pr.airconditioningtypeid = air.airconditioningtypeid
	Left Join architecturalstyletype as ar
		on  pr.architecturalstyletypeid = ar.architecturalstyletypeid
	Left Join buildingclasstype as bu
		on pr.buildingclasstypeid = bu.buildingclasstypeid
	Left Join heatingorsystemtype as he
		on pr.heatingorsystemtypeid = he.heatingorsystemtypeid
	Left Join propertylandusetype po
		on pr.propertylandusetypeid = po.propertylandusetypeid
	Left Join storytype as st
		on pr.storytypeid = st.storytypeid
	Left Join typeconstructiontype as ty
		on pr.typeconstructiontypeid = ty.typeconstructiontypeid
    Left Join unique_properties as up
		on pr.parcelid = up.parcelid
	Where 
		YEAR(predictions_2017.transactiondate) = 2017
        AND (pr.latitude IS NOT NULL AND pr.longitude IS NOT NULL);'''

# %%
sql_query = """
SELECT prop.*, 
       pred.logerror, 
       pred.transactiondate, 
       air.airconditioningdesc, 
       arch.architecturalstyledesc, 
       build.buildingclassdesc, 
       heat.heatingorsystemdesc, 
       landuse.propertylandusedesc, 
       story.storydesc, 
       construct.typeconstructiondesc 

FROM   properties_2017 prop  
       INNER JOIN (SELECT parcelid,
       					  logerror,
                          Max(transactiondate) transactiondate 
                   FROM   predictions_2017 
                   GROUP  BY parcelid, logerror) pred
               USING (parcelid) 
       LEFT JOIN airconditioningtype air USING (airconditioningtypeid) 
       LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid) 
       LEFT JOIN buildingclasstype build USING (buildingclasstypeid) 
       LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid) 
       LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid) 
       LEFT JOIN storytype story USING (storytypeid) 
       LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid) 
WHERE  prop.latitude IS NOT NULL 
       AND prop.longitude IS NOT NULL AND transactiondate <= '2017-12-31' 
"""

# %%
# make sure the sql query works:
df = pd.read_sql(sql_query, get_db_url('zillow'))
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# 1                    NaN                1.0  ...         6.111001e+13
# 2                    NaN                2.0  ...         6.059022e+13
# 3                    8.0                3.0  ...         6.037300e+13
# 4                    8.0                3.0  ...         6.037124e+13
#
#    logerror  transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0  0.025595       2017-01-01                 None                    None
# 1  0.055619       2017-01-01                 None                    None
# 2  0.005383       2017-01-01                 None                    None
# 3 -0.103410       2017-01-01                 None                    None
# 4  0.006940       2017-01-01              Central                    None
#
#    buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0               None                 None  Single Family Residential
# 1               None                 None  Single Family Residential
# 2               None                 None  Single Family Residential
# 3               None              Central  Single Family Residential
# 4               None              Central                Condominium
#
#    storydesc  typeconstructiondesc
# 0       None                  None
# 1       None                  None
# 2       None                  None
# 3       None                  None
# 4       None                  None
#
# [5 rows x 68 columns]

# %%
# are there anu duplicates?
duplicate_rows = df[df.duplicated(keep='first')]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [id, parcelid, airconditioningtypeid, architecturalstyletypeid, basementsqft, bathroomcnt, bedroomcnt, buildingclasstypeid, buildingqualitytypeid, calculatedbathnbr, decktypeid, finishedfloor1squarefeet, calculatedfinishedsquarefeet, finishedsquarefeet12, finishedsquarefeet13, finishedsquarefeet15, finishedsquarefeet50, finishedsquarefeet6, fips, fireplacecnt, fullbathcnt, garagecarcnt, garagetotalsqft, hashottuborspa, heatingorsystemtypeid, latitude, longitude, lotsizesquarefeet, poolcnt, poolsizesum, pooltypeid10, pooltypeid2, pooltypeid7, propertycountylandusecode, propertylandusetypeid, propertyzoningdesc, rawcensustractandblock, regionidcity, regionidcounty, regionidneighborhood, regionidzip, roomcnt, storytypeid, threequarterbathnbr, typeconstructiontypeid, unitcnt, yardbuildingsqft17, yardbuildingsqft26, yearbuilt, numberofstories, fireplaceflag, structuretaxvaluedollarcnt, taxvaluedollarcnt, assessmentyear, landtaxvaluedollarcnt, taxamount, taxdelinquencyflag, taxdelinquencyyear, censustractandblock, logerror, transactiondate, airconditioningdesc, architecturalstyledesc, buildingclassdesc, heatingorsystemdesc, propertylandusedesc, storydesc, typeconstructiondesc]
# Index: []
#
# [0 rows x 68 columns]

# %%
def read_zillow():
    '''
    This function return a zillow based on the following requirements:
    - Only unclude propeties with a transaction in 2017
    - Include only the last transaction for each property
    - Include only the last zestimate error and date of transaction
    - Only include properties that have a latitude and longitude value.
    '''
    sql_query: sql_query = '''
    SELECT prop.*, 
       pred.logerror, 
       pred.transactiondate, 
       air.airconditioningdesc, 
       arch.architecturalstyledesc, 
       build.buildingclassdesc, 
       heat.heatingorsystemdesc, 
       landuse.propertylandusedesc, 
       story.storydesc, 
       construct.typeconstructiondesc 

FROM   properties_2017 prop  
       INNER JOIN (SELECT parcelid,
       					  logerror,
                          Max(transactiondate) transactiondate 
                   FROM   predictions_2017 
                   GROUP  BY parcelid, logerror) pred
               USING (parcelid) 
       LEFT JOIN airconditioningtype air USING (airconditioningtypeid) 
       LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid) 
       LEFT JOIN buildingclasstype build USING (buildingclasstypeid) 
       LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid) 
       LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid) 
       LEFT JOIN storytype story USING (storytypeid) 
       LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid) 
WHERE  prop.latitude IS NOT NULL 
       AND prop.longitude IS NOT NULL AND transactiondate <= '2017-12-31' '''
    
    # return the data frame
    return pd.read_sql(sql_query, get_db_url('zillow'))

# %%
def get_zillow_data():
    '''
    This function reads in data from a codeup database, writes the data to a csv file if a 
    local file does not exist, and returns a df
    '''
    
    if os.path.isfile('zillow.csv'):
        
        #if csv file exists, read in data from csv file 
        df = pd.read_csv('zillow.csv', index_col = 0)
        
    else:
        
        # read fresh data from db into a dataframe
        df = read_zillow()
        
        #write dataframe to a csv file
        df.to_csv('zillow.csv')
    
    return df

# %%
get_zillow_data()
# Out:
# /var/folders/jn/cmfcvpnn3h7cl7fbnrfj71c40000gn/T/ipykernel_35209/732780723.py:10: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow.csv', index_col = 0)
#             id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0      1727539  14297519                    NaN                       NaN
# 1      1387261  17052889                    NaN                       NaN
# 2        11677  14186244                    NaN                       NaN
# 3      2288172  12177905                    NaN                       NaN
# 4      1970746  10887214                    1.0                       NaN
# ...        ...       ...                    ...                       ...
# 77569  2864704  10833991                    1.0                       NaN
# 77570   673515  11000655                    NaN                       NaN
# 77571  2968375  17239384                    NaN                       NaN
# 77572  1843709  12773139                    1.0                       NaN
# 77573  1187175  12826780                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0               NaN          3.5         4.0                  NaN
# 1               NaN          1.0         2.0                  NaN
# 2               NaN          2.0         3.0                  NaN
# 3               NaN          3.0         4.0                  NaN
# 4               NaN          3.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 77569           NaN          3.0         3.0                  NaN
# 77570           NaN          2.0         2.0                  NaN
# 77571           NaN          2.0         4.0                  NaN
# 77572           NaN          1.0         3.0                  NaN
# 77573           NaN          2.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                        NaN                3.5  ...         6.059063e+13
# 1                        NaN                1.0  ...         6.111001e+13
# 2                        NaN                2.0  ...         6.059022e+13
# 3                        8.0                3.0  ...         6.037300e+13
# 4                        8.0                3.0  ...         6.037124e+13
# ...                      ...                ...  ...                  ...
# 77569                    8.0                3.0  ...         6.037132e+13
# 77570                    6.0                2.0  ...         6.037101e+13
# 77571                    NaN                2.0  ...         6.111008e+13
# 77572                    4.0                1.0  ...         6.037434e+13
# 77573                    6.0                2.0  ...         6.037503e+13
#
#        logerror  transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0      0.025595       2017-01-01                  NaN                     NaN
# 1      0.055619       2017-01-01                  NaN                     NaN
# 2      0.005383       2017-01-01                  NaN                     NaN
# 3     -0.103410       2017-01-01                  NaN                     NaN
# 4      0.006940       2017-01-01              Central                     NaN
# ...         ...              ...                  ...                     ...
# 77569 -0.002245       2017-09-20              Central                     NaN
# 77570  0.020615       2017-09-20                  NaN                     NaN
# 77571  0.013209       2017-09-21                  NaN                     NaN
# 77572  0.037129       2017-09-21              Central                     NaN
# 77573  0.007204       2017-09-25                  NaN                     NaN
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                    NaN                  NaN  Single Family Residential
# 1                    NaN                  NaN  Single Family Residential
# 2                    NaN                  NaN  Single Family Residential
# 3                    NaN              Central  Single Family Residential
# 4                    NaN              Central                Condominium
# ...                  ...                  ...                        ...
# 77569                NaN              Central                Condominium
# 77570                NaN              Central  Single Family Residential
# 77571                NaN                  NaN  Single Family Residential
# 77572                NaN              Central  Single Family Residential
# 77573                NaN              Central  Single Family Residential
#
#        storydesc  typeconstructiondesc
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
# 3            NaN                   NaN
# 4            NaN                   NaN
# ...          ...                   ...
# 77569        NaN                   NaN
# 77570        NaN                   NaN
# 77571        NaN                   NaN
# 77572        NaN                   NaN
# 77573        NaN                   NaN
#
# [77574 rows x 68 columns]

# %% [markdown]
# ### 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)

# %%
df.describe()
# Out:
#                  id      parcelid  airconditioningtypeid  \
# count  7.757400e+04  7.757400e+04           25006.000000
# mean   1.495340e+06  1.300630e+07               1.812045
# std    8.609689e+05  3.478043e+06               2.965823
# min    3.490000e+02  1.071186e+07               1.000000
# 25%    7.520875e+05  1.153819e+07               1.000000
# 50%    1.498169e+06  1.253050e+07               1.000000
# 75%    2.240588e+06  1.421124e+07               1.000000
# max    2.982274e+06  1.676893e+08              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                206.000000     50.000000  77574.000000  77574.000000
# mean                   7.388350    679.720000      2.298521      3.053252
# std                    2.734542    689.703546      0.996706      1.140447
# min                    2.000000     38.000000      0.000000      0.000000
# 25%                    7.000000    273.000000      2.000000      2.000000
# 50%                    7.000000    515.000000      2.000000      3.000000
# 75%                    7.000000    796.500000      3.000000      4.000000
# max                   21.000000   3560.000000     18.000000     16.000000
#
#        buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  ...  \
# count            15.000000           49808.000000       76959.000000  ...
# mean              3.933333               6.533830           2.316389  ...
# std               0.258199               1.722041           0.979690  ...
# min               3.000000               1.000000           1.000000  ...
# 25%               4.000000               6.000000           2.000000  ...
# 50%               4.000000               6.000000           2.000000  ...
# 75%               4.000000               8.000000           3.000000  ...
# max               4.000000              12.000000          18.000000  ...
#
#        numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# count     17596.000000          172.0                7.745900e+04
# mean          1.434246            1.0                1.892829e+05
# std           0.544518            0.0                2.304149e+05
# min           1.000000            1.0                4.400000e+01
# 25%           1.000000            1.0                8.418200e+04
# 50%           1.000000            1.0                1.364070e+05
# 75%           2.000000            1.0                2.187340e+05
# max           6.000000            1.0                1.142179e+07
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  \
# count       7.757300e+04         77574.0           7.757200e+04
# mean        4.901477e+05          2016.0           3.011468e+05
# std         6.538059e+05             0.0           4.927317e+05
# min         1.000000e+03          2016.0           1.610000e+02
# 25%         2.068980e+05          2016.0           8.529200e+04
# 50%         3.588790e+05          2016.0           2.031810e+05
# 75%         5.690000e+05          2016.0           3.667610e+05
# max         4.906124e+07          2016.0           4.895220e+07
#
#            taxamount  taxdelinquencyyear  censustractandblock      logerror
# count   77569.000000         2900.000000         7.732700e+04  77574.000000
# mean     5995.855691           14.088276         6.049666e+13      0.016805
# std      7628.912331            2.181281         1.533386e+12      0.170742
# min        19.920000            3.000000         6.037101e+13     -4.655420
# 25%      2712.610000           14.000000         6.037311e+13     -0.024310
# 50%      4448.300000           15.000000         6.037603e+13      0.006673
# 75%      6926.820000           15.000000         6.059042e+13      0.039292
# max    586639.300000           99.000000         4.830301e+14      5.262999
#
# [8 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77574 entries, 0 to 77573
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77574 non-null  int64
#  1   parcelid                      77574 non-null  int64
#  2   airconditioningtypeid         25006 non-null  float64
#  3   architecturalstyletypeid      206 non-null    float64
#  4   basementsqft                  50 non-null     float64
#  5   bathroomcnt                   77574 non-null  float64
#  6   bedroomcnt                    77574 non-null  float64
#  7   buildingclasstypeid           15 non-null     float64
#  8   buildingqualitytypeid         49808 non-null  float64
#  9   calculatedbathnbr             76959 non-null  float64
#  10  decktypeid                    614 non-null    float64
#  11  finishedfloor1squarefeet      6035 non-null   float64
#  12  calculatedfinishedsquarefeet  77374 non-null  float64
#  13  finishedsquarefeet12          73919 non-null  float64
#  14  finishedsquarefeet13          42 non-null     float64
#  15  finishedsquarefeet15          3027 non-null   float64
#  16  finishedsquarefeet50          6035 non-null   float64
#  17  finishedsquarefeet6           386 non-null    float64
#  18  fips                          77574 non-null  float64
#  19  fireplacecnt                  8287 non-null   float64
#  20  fullbathcnt                   76959 non-null  float64
#  21  garagecarcnt                  25517 non-null  float64
#  22  garagetotalsqft               25517 non-null  float64
#  23  hashottuborspa                1539 non-null   float64
#  24  heatingorsystemtypeid         49569 non-null  float64
#  25  latitude                      77574 non-null  float64
#  26  longitude                     77574 non-null  float64
#  27  lotsizesquarefeet             69317 non-null  float64
#  28  poolcnt                       16173 non-null  float64
#  29  poolsizesum                   869 non-null    float64
#  30  pooltypeid10                  465 non-null    float64
#  31  pooltypeid2                   1074 non-null   float64
#  32  pooltypeid7                   15078 non-null  float64
#  33  propertycountylandusecode     77574 non-null  object
#  34  propertylandusetypeid         77574 non-null  float64
#  35  propertyzoningdesc            50474 non-null  object
#  36  rawcensustractandblock        77574 non-null  float64
#  37  regionidcity                  76102 non-null  float64
#  38  regionidcounty                77574 non-null  float64
#  39  regionidneighborhood          30973 non-null  float64
#  40  regionidzip                   77524 non-null  float64
#  41  roomcnt                       77574 non-null  float64
#  42  storytypeid                   50 non-null     float64
#  43  threequarterbathnbr           10105 non-null  float64
#  44  typeconstructiontypeid        222 non-null    float64
#  45  unitcnt                       50702 non-null  float64
#  46  yardbuildingsqft17            2393 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77305 non-null  float64
#  49  numberofstories               17596 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77459 non-null  float64
#  52  taxvaluedollarcnt             77573 non-null  float64
#  53  assessmentyear                77574 non-null  float64
#  54  landtaxvaluedollarcnt         77572 non-null  float64
#  55  taxamount                     77569 non-null  float64
#  56  taxdelinquencyflag            2900 non-null   object
#  57  taxdelinquencyyear            2900 non-null   float64
#  58  censustractandblock           77327 non-null  float64
#  59  logerror                      77574 non-null  float64
#  60  transactiondate               77574 non-null  object
#  61  airconditioningdesc           25006 non-null  object
#  62  architecturalstyledesc        206 non-null    object
#  63  buildingclassdesc             15 non-null     object
#  64  heatingorsystemdesc           49569 non-null  object
#  65  propertylandusedesc           77574 non-null  object
#  66  storydesc                     50 non-null     object
#  67  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(2), object(11)
# memory usage: 40.2+ MB

# %%
df.shape
# Out:
# (77574, 68)

# %% [markdown]
# ### 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
# missing values in columns: 
df.isna().sum()
# Out:
# id                              0
# parcelid                        0
# airconditioningtypeid       52568
# architecturalstyletypeid    77368
# basementsqft                77524
#                             ...
# buildingclassdesc           77559
# heatingorsystemdesc         28005
# propertylandusedesc             0
# storydesc                   77524
# typeconstructiondesc        77352
# Length: 68, dtype: int64

# %%
# missing values in rows: 
df.isna().sum(axis=1)
# Out:
# 0        36
# 1        33
# 2        34
# 3        32
# 4        29
#          ..
# 77569    29
# 77570    33
# 77571    32
# 77572    32
# 77573    34
# Length: 77574, dtype: int64

# %%
df_nulls = df.copy().T
df_nulls
# Out:
#                                               0      \
# id                                          1727539
# parcelid                                   14297519
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               1      \
# id                                          1387261
# parcelid                                   17052889
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               2      \
# id                                            11677
# parcelid                                   14186244
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               3            4            5      \
# id                                          2288172      1970746      1447245
# parcelid                                   12177905     10887214     17143294
# airconditioningtypeid                           NaN          1.0          NaN
# architecturalstyletypeid                        NaN          NaN          NaN
# basementsqft                                    NaN          NaN          NaN
# ...                                             ...          ...          ...
# buildingclassdesc                              None         None         None
# heatingorsystemdesc                         Central      Central         None
# propertylandusedesc       Single Family Residential  Condominium  Condominium
# storydesc                                      None         None         None
# typeconstructiondesc                           None         None         None
#
#                                               6      \
# id                                           781532
# parcelid                                   12095076
# airconditioningtypeid                           1.0
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               7      \
# id                                           870991
# parcelid                                   12069064
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               8            9      ...  \
# id                                          1246926      1585097  ...
# parcelid                                   12790562     11542646  ...
# airconditioningtypeid                           NaN          NaN  ...
# architecturalstyletypeid                        NaN          NaN  ...
# basementsqft                                    NaN          NaN  ...
# ...                                             ...          ...  ...
# buildingclassdesc                              None         None  ...
# heatingorsystemdesc                         Central      Central  ...
# propertylandusedesc       Single Family Residential  Condominium  ...
# storydesc                                      None         None  ...
# typeconstructiondesc                           None         None  ...
#
#                                               77564        77565        77566  \
# id                                          1635173      1684937      1642435
# parcelid                                   12892446     12666457     10858613
# airconditioningtypeid                           NaN          NaN          1.0
# architecturalstyletypeid                        NaN          NaN          NaN
# basementsqft                                    NaN          NaN          NaN
# ...                                             ...          ...          ...
# buildingclassdesc                              None         None         None
# heatingorsystemdesc                         Central      Central      Central
# propertylandusedesc       Single Family Residential  Condominium  Condominium
# storydesc                                      None         None         None
# typeconstructiondesc                           None         None         None
#
#                                               77567  \
# id                                          1373391
# parcelid                                   10722691
# airconditioningtypeid                           1.0
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77568        77569  \
# id                                          2274245      2864704
# parcelid                                   12412492     10833991
# airconditioningtypeid                           NaN          1.0
# architecturalstyletypeid                        NaN          NaN
# basementsqft                                    NaN          NaN
# ...                                             ...          ...
# buildingclassdesc                              None         None
# heatingorsystemdesc                         Central      Central
# propertylandusedesc       Single Family Residential  Condominium
# storydesc                                      None         None
# typeconstructiondesc                           None         None
#
#                                               77570  \
# id                                           673515
# parcelid                                   11000655
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77571  \
# id                                          2968375
# parcelid                                   17239384
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77572                      77573
# id                                          1843709                    1187175
# parcelid                                   12773139                   12826780
# airconditioningtypeid                           1.0                        NaN
# architecturalstyletypeid                        NaN                        NaN
# basementsqft                                    NaN                        NaN
# ...                                             ...                        ...
# buildingclassdesc                              None                       None
# heatingorsystemdesc                         Central                    Central
# propertylandusedesc       Single Family Residential  Single Family Residential
# storydesc                                      None                       None
# typeconstructiondesc                           None                       None
#
# [68 rows x 77574 columns]

# %%
df_nulls['num_rows_missing'] = df.isna().sum(axis=0)
df_nulls
# Out:
#                                                   0  \
# id                                          1727539
# parcelid                                   14297519
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                                   1  \
# id                                          1387261
# parcelid                                   17052889
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                                   2  \
# id                                            11677
# parcelid                                   14186244
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                                   3            4            5  \
# id                                          2288172      1970746      1447245
# parcelid                                   12177905     10887214     17143294
# airconditioningtypeid                           NaN          1.0          NaN
# architecturalstyletypeid                        NaN          NaN          NaN
# basementsqft                                    NaN          NaN          NaN
# ...                                             ...          ...          ...
# buildingclassdesc                              None         None         None
# heatingorsystemdesc                         Central      Central         None
# propertylandusedesc       Single Family Residential  Condominium  Condominium
# storydesc                                      None         None         None
# typeconstructiondesc                           None         None         None
#
#                                                   6  \
# id                                           781532
# parcelid                                   12095076
# airconditioningtypeid                           1.0
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                                   7  \
# id                                           870991
# parcelid                                   12069064
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                                   8            9  ...  \
# id                                          1246926      1585097  ...
# parcelid                                   12790562     11542646  ...
# airconditioningtypeid                           NaN          NaN  ...
# architecturalstyletypeid                        NaN          NaN  ...
# basementsqft                                    NaN          NaN  ...
# ...                                             ...          ...  ...
# buildingclassdesc                              None         None  ...
# heatingorsystemdesc                         Central      Central  ...
# propertylandusedesc       Single Family Residential  Condominium  ...
# storydesc                                      None         None  ...
# typeconstructiondesc                           None         None  ...
#
#                                 77565        77566                      77567  \
# id                            1684937      1642435                    1373391
# parcelid                     12666457     10858613                   10722691
# airconditioningtypeid             NaN          1.0                        1.0
# architecturalstyletypeid          NaN          NaN                        NaN
# basementsqft                      NaN          NaN                        NaN
# ...                               ...          ...                        ...
# buildingclassdesc                None         None                       None
# heatingorsystemdesc           Central      Central                    Central
# propertylandusedesc       Condominium  Condominium  Single Family Residential
# storydesc                        None         None                       None
# typeconstructiondesc             None         None                       None
#
#                                               77568        77569  \
# id                                          2274245      2864704
# parcelid                                   12412492     10833991
# airconditioningtypeid                           NaN          1.0
# architecturalstyletypeid                        NaN          NaN
# basementsqft                                    NaN          NaN
# ...                                             ...          ...
# buildingclassdesc                              None         None
# heatingorsystemdesc                         Central      Central
# propertylandusedesc       Single Family Residential  Condominium
# storydesc                                      None         None
# typeconstructiondesc                           None         None
#
#                                               77570  \
# id                                           673515
# parcelid                                   11000655
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77571  \
# id                                          2968375
# parcelid                                   17239384
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                            None
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77572  \
# id                                          1843709
# parcelid                                   12773139
# airconditioningtypeid                           1.0
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# ...                                             ...
# buildingclassdesc                              None
# heatingorsystemdesc                         Central
# propertylandusedesc       Single Family Residential
# storydesc                                      None
# typeconstructiondesc                           None
#
#                                               77573 num_rows_missing
# id                                          1187175                0
# parcelid                                   12826780                0
# airconditioningtypeid                           NaN            52568
# architecturalstyletypeid                        NaN            77368
# basementsqft                                    NaN            77524
# ...                                             ...              ...
# buildingclassdesc                              None            77559
# heatingorsystemdesc                         Central            28005
# propertylandusedesc       Single Family Residential                0
# storydesc                                      None            77524
# typeconstructiondesc                           None            77352
#
# [68 rows x 77575 columns]

# %%
df_nulls['pct_rows_missing'] = (df.isna().sum(axis=0)/df.shape[0])

# %%
df_null = df_nulls[['num_rows_missing','pct_rows_missing']]
df_null
# Out:
#                           num_rows_missing  pct_rows_missing
# id                                       0          0.000000
# parcelid                                 0          0.000000
# airconditioningtypeid                52568          0.677650
# architecturalstyletypeid             77368          0.997344
# basementsqft                         77524          0.999355
# ...                                    ...               ...
# buildingclassdesc                    77559          0.999807
# heatingorsystemdesc                  28005          0.361010
# propertylandusedesc                      0          0.000000
# storydesc                            77524          0.999355
# typeconstructiondesc                 77352          0.997138
#
# [68 rows x 2 columns]

# %%
def nulls_by_col(df):
    num_missing = df.isnull().sum()
    rows = df.shape[0]
    pct_missing = num_missing / rows
    cols_missing = pd.DataFrame({'number_missing_rows': num_missing, 'percent_rows_missing': pct_missing})
    return cols_missing

# %%
nulls_by_col(df)
# Out:
#                           number_missing_rows  percent_rows_missing
# id                                          0              0.000000
# parcelid                                    0              0.000000
# airconditioningtypeid                   52568              0.677650
# architecturalstyletypeid                77368              0.997344
# basementsqft                            77524              0.999355
# ...                                       ...                   ...
# buildingclassdesc                       77559              0.999807
# heatingorsystemdesc                     28005              0.361010
# propertylandusedesc                         0              0.000000
# storydesc                               77524              0.999355
# typeconstructiondesc                    77352              0.997138
#
# [68 rows x 2 columns]

# %% [markdown]
# # Prepare:

# %% [markdown]
# ### 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.

# %%
# Restrict df to only properties that meet single unit criteria

single_use = [261, 262, 263, 264, 266, 268, 273, 276, 279]
df = df[df.propertylandusetypeid.isin(single_use)]
    
    
# Restrict df to only those properties with at least 1 bath & bed and >350 sqft area
df = df[(df.bedroomcnt > 0) & (df.bathroomcnt > 0) & ((df.unitcnt<=1)|df.unitcnt.isnull()) & (df.calculatedfinishedsquarefeet>350)]

# %%
def handle_missing_values(df, prop_required_column = .5, prop_required_row = .70):
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    return df

# %%
df = handle_missing_values(df)
df.head()
# Out:
#         id  parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  1727539  14297519          3.5         4.0                    NaN
# 1  1387261  17052889          1.0         2.0                    NaN
# 2    11677  14186244          2.0         3.0                    NaN
# 3  2288172  12177905          3.0         4.0                    8.0
# 4  1970746  10887214          3.0         3.0                    8.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                3.5                        3100.0                3100.0
# 1                1.0                        1465.0                1465.0
# 2                2.0                        1243.0                1243.0
# 3                3.0                        2376.0                2376.0
# 4                3.0                        1312.0                1312.0
#
#      fips  fullbathcnt  ...  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0  6059.0          3.0  ...                    485713.0          1023282.0
# 1  6111.0          1.0  ...                     88000.0           464000.0
# 2  6059.0          2.0  ...                     85289.0           564778.0
# 3  6037.0          3.0  ...                    108918.0           145143.0
# 4  6037.0          3.0  ...                     73681.0           119407.0
#
#    assessmentyear  landtaxvaluedollarcnt taxamount  censustractandblock  \
# 0          2016.0               537569.0  11013.72         6.059063e+13
# 1          2016.0               376000.0   5672.48         6.111001e+13
# 2          2016.0               479489.0   6488.30         6.059022e+13
# 3          2016.0                36225.0   1777.51         6.037300e+13
# 4          2016.0                45726.0   1533.89         6.037124e+13
#
#    logerror  transactiondate  heatingorsystemdesc        propertylandusedesc
# 0  0.025595       2017-01-01                 None  Single Family Residential
# 1  0.055619       2017-01-01                 None  Single Family Residential
# 2  0.005383       2017-01-01                 None  Single Family Residential
# 3 -0.103410       2017-01-01              Central  Single Family Residential
# 4  0.006940       2017-01-01              Central                Condominium
#
# [5 rows x 34 columns]

# %%
# columns to remove based on outliers

cols_to_remove = ['id',
       'calculatedbathnbr', 'finishedsquarefeet12', 'fullbathcnt', 'heatingorsystemtypeid'
       ,'propertycountylandusecode', 'propertylandusetypeid','propertyzoningdesc', 
        'censustractandblock', 'propertylandusedesc', 'unitcnt']

# %%
def remove_columns(df, cols_to_remove):  
    df = df.drop(columns=cols_to_remove)
    return df

# %%
df = remove_columns(df, cols_to_remove)

# %%
df.isnull().sum()
# Out:
# parcelid                            0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           26514
# calculatedfinishedsquarefeet        0
# fips                                0
# latitude                            0
# longitude                           0
# lotsizesquarefeet                8034
# rawcensustractandblock              0
# regionidcity                     1322
# regionidcounty                      0
# regionidzip                        40
# roomcnt                             0
# yearbuilt                          35
# structuretaxvaluedollarcnt         75
# taxvaluedollarcnt                   1
# assessmentyear                      0
# landtaxvaluedollarcnt               1
# taxamount                           5
# logerror                            0
# transactiondate                     0
# heatingorsystemdesc             24943
# dtype: int64

# %%
# messy column
df.drop(columns = 'heatingorsystemdesc', inplace = True)

# %%
# fill in nulls
df.buildingqualitytypeid.fillna(6.0, inplace = True)

# %%
# fill in nulls
df.lotsizesquarefeet.fillna(7313, inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69919 entries, 0 to 77573
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      69919 non-null  int64
#  1   bathroomcnt                   69919 non-null  float64
#  2   bedroomcnt                    69919 non-null  float64
#  3   buildingqualitytypeid         69919 non-null  float64
#  4   calculatedfinishedsquarefeet  69919 non-null  float64
#  5   fips                          69919 non-null  float64
#  6   latitude                      69919 non-null  float64
#  7   longitude                     69919 non-null  float64
#  8   lotsizesquarefeet             69919 non-null  float64
#  9   rawcensustractandblock        69919 non-null  float64
#  10  regionidcity                  69919 non-null  float64
#  11  regionidcounty                69919 non-null  float64
#  12  regionidzip                   69919 non-null  float64
#  13  roomcnt                       69919 non-null  float64
#  14  yearbuilt                     69919 non-null  float64
#  15  structuretaxvaluedollarcnt    69919 non-null  float64
#  16  taxvaluedollarcnt             69919 non-null  float64
#  17  assessmentyear                69919 non-null  float64
#  18  landtaxvaluedollarcnt         69919 non-null  float64
#  19  taxamount                     69919 non-null  float64
#  20  logerror                      69919 non-null  float64
#  21  transactiondate               69919 non-null  object
# dtypes: float64(20), int64(1), object(1)
# memory usage: 12.3+ MB

# %%
#Remove outliers: 
df = df[df.taxvaluedollarcnt < 5_000_000]
df[df.calculatedfinishedsquarefeet < 8000]
# Out:
#        parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0      14297519          3.5         4.0                    6.0
# 1      17052889          1.0         2.0                    6.0
# 2      14186244          2.0         3.0                    6.0
# 3      12177905          3.0         4.0                    8.0
# 4      10887214          3.0         3.0                    8.0
# ...         ...          ...         ...                    ...
# 77569  10833991          3.0         3.0                    8.0
# 77570  11000655          2.0         2.0                    6.0
# 77571  17239384          2.0         4.0                    6.0
# 77572  12773139          1.0         3.0                    4.0
# 77573  12826780          2.0         3.0                    6.0
#
#        calculatedfinishedsquarefeet    fips    latitude    longitude  \
# 0                            3100.0  6059.0  33634931.0 -117869207.0
# 1                            1465.0  6111.0  34449266.0 -119281531.0
# 2                            1243.0  6059.0  33886168.0 -117823170.0
# 3                            2376.0  6037.0  34245180.0 -118240722.0
# 4                            1312.0  6037.0  34185120.0 -118414640.0
# ...                             ...     ...         ...          ...
# 77569                        1741.0  6037.0  34202400.0 -118502000.0
# 77570                        1286.0  6037.0  34245368.0 -118282383.0
# 77571                        1612.0  6111.0  34300140.0 -118706327.0
# 77572                        1032.0  6037.0  34040895.0 -118038169.0
# 77573                        1762.0  6037.0  33937685.0 -117996709.0
#
#        lotsizesquarefeet  rawcensustractandblock  ...  regionidzip  roomcnt  \
# 0                 4506.0            6.059063e+07  ...      96978.0      0.0
# 1                12647.0            6.111001e+07  ...      97099.0      5.0
# 2                 8432.0            6.059022e+07  ...      97078.0      6.0
# 3                13038.0            6.037300e+07  ...      96330.0      0.0
# 4               278581.0            6.037124e+07  ...      96451.0      0.0
# ...                  ...                     ...  ...          ...      ...
# 77569            59487.0            6.037132e+07  ...      96415.0      0.0
# 77570            47405.0            6.037101e+07  ...      96284.0      0.0
# 77571            12105.0            6.111008e+07  ...      97116.0      7.0
# 77572             5074.0            6.037434e+07  ...      96480.0      0.0
# 77573             6347.0            6.037503e+07  ...      96171.0      0.0
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0         1998.0                    485713.0          1023282.0
# 1         1967.0                     88000.0           464000.0
# 2         1962.0                     85289.0           564778.0
# 3         1970.0                    108918.0           145143.0
# 4         1964.0                     73681.0           119407.0
# ...          ...                         ...                ...
# 77569     1980.0                    265000.0           379000.0
# 77570     1940.0                     70917.0           354621.0
# 77571     1964.0                     50683.0            67205.0
# 77572     1954.0                     32797.0            49546.0
# 77573     1955.0                    140000.0           522000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  logerror  \
# 0              2016.0               537569.0   11013.72  0.025595
# 1              2016.0               376000.0    5672.48  0.055619
# 2              2016.0               479489.0    6488.30  0.005383
# 3              2016.0                36225.0    1777.51 -0.103410
# 4              2016.0                45726.0    1533.89  0.006940
# ...               ...                    ...        ...       ...
# 77569          2016.0               114000.0    4685.34 -0.002245
# 77570          2016.0               283704.0    4478.43  0.020615
# 77571          2016.0                16522.0    1107.48  0.013209
# 77572          2016.0                16749.0     876.43  0.037129
# 77573          2016.0               382000.0    6317.15  0.007204
#
#        transactiondate
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 77569       2017-09-20
# 77570       2017-09-20
# 77571       2017-09-21
# 77572       2017-09-21
# 77573       2017-09-25
#
# [69680 rows x 22 columns]

# %%
# Function to read and wrangle data:

def wrangle_zillow():
    df = pd.read_csv('zillow.csv')
    
    # Restrict df to only properties that meet single unit use criteria
    single_use = [261, 262, 263, 264, 266, 268, 273, 276, 279]
    df = df[df.propertylandusetypeid.isin(single_use)]
    
    # Restrict df to only those properties with at least 1 bath & bed and 350 sqft area
    df = df[(df.bedroomcnt > 0) & (df.bathroomcnt > 0) & ((df.unitcnt<=1)|df.unitcnt.isnull())\
            & (df.calculatedfinishedsquarefeet>350)]

    # Handle missing values i.e. drop columns and rows based on a threshold
    df = handle_missing_values(df)
    
    # Add column for counties
    df['county'] = np.where(df.fips == 6037, 'Los_Angeles',
                           np.where(df.fips == 6059, 'Orange', 
                                   'Ventura'))    
    # drop columns not needed
    df = remove_columns(df, ['id',
       'calculatedbathnbr', 'finishedsquarefeet12', 'fullbathcnt', 'heatingorsystemtypeid'
       ,'propertycountylandusecode', 'propertylandusetypeid','propertyzoningdesc', 
        'censustractandblock', 'propertylandusedesc','heatingorsystemdesc','unitcnt'
                            ,'buildingqualitytypeid'])


    # replace nulls in unitcnt with 1
#     df.unitcnt.fillna(1, inplace = True)
    
    # assume that since this is Southern CA, null means 'None' for heating system
#     df.heatingorsystemdesc.fillna('None', inplace = True)
    
    # replace nulls with median values for select columns
    df.lotsizesquarefeet.fillna(7313, inplace = True)
#     df.buildingqualitytypeid.fillna(6.0, inplace = True)

    # Columns to look for outliers
    df = df[df.taxvaluedollarcnt < 5_000_000]
    df[df.calculatedfinishedsquarefeet < 8000]
    
    # Just to be sure we caught all nulls, drop them here
    df = df.dropna()
    
    return df

# %% [markdown]
# # Mall Customers:
# - Acquire data from the customers table in the mall_customers database.
# - Summarize the data (include distributions and descriptive statistics).
# - Detect outliers using IQR.
# - Split data into train, validate, and test.
# - Encode categorical columns using a one hot encoder (pd.get_dummies).
# - Handles missing values.
# - Scaling

# %%
def wrangle_mall_df():
    
    # acquire data
    sql = 'select * from customers'
    mall_df = get_mall_customers(sql)
    
    # handle outliers
    mall_df = outlier_function(mall_df, ['age', 'spending_score', 'annual_income'], 1.5)
    
    # get dummy for gender column
    dummy_df = pd.get_dummies(mall_df.gender, drop_first=True)
    mall_df = pd.concat([mall_df, dummy_df], axis=1).drop(columns = ['gender'])
    mall_df.rename(columns= {'Male': 'is_male'}, inplace = True)

    # split the data in train, validate and test
    train, test = train_test_split(mall_df, train_size = 0.8, random_state = 123)
    train, validate = train_test_split(train, train_size = 0.75, random_state = 123)
    
    return min_max_scaler, train, validate, test

# %%
def min_max_scaler(train, valid, test):
    '''
    Uses the train & test datasets created by the split_my_data function
    Returns 3 items: mm_scaler, train_scaled_mm, test_scaled_mm
    This is a linear transformation. Values will lie between 0 and 1
    '''
    num_vars = list(train.select_dtypes('number').columns)
    scaler = MinMaxScaler(copy=True, feature_range=(0,1))
    train[num_vars] = scaler.fit_transform(train[num_vars])
    valid[num_vars] = scaler.transform(valid[num_vars])
    test[num_vars] = scaler.transform(test[num_vars])
    return scaler, train, valid, test
